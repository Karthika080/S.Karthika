# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  0.154936 -1.330841 -0.144834
# b       NaN       NaN       NaN
# c  0.551502 -0.176328 -0.656080
# d  0.346915  0.204513 -1.411731
# e       NaN       NaN       NaN
# f  0.832735 -0.448592  0.866400
#
#
# Dropped DataFrame
#          one       two     three
# a  0.154936 -1.330841 -0.144834
# c  0.551502 -0.176328 -0.656080
# d  0.346915  0.204513 -1.411731
# f  0.832735 -0.448592  0.866400

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -1.624835 -0.313261  0.532412
# b       NaN       NaN       NaN
# c -0.122810 -0.837193  0.163956
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -1.624835 -0.313261  0.532412
# b  0.000000  0.000000  0.000000
# c -0.122810 -0.837193  0.163956

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DtaFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DtaFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a -0.153087  0.652619  1.004009
# b       NaN       NaN       NaN
# c  1.060895 -0.485824 -0.235091
# d -0.873011  0.411354  1.651738
# e       NaN       NaN       NaN
# f -0.558049  0.150097  0.479476
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.053098 -2.102404  0.848131
# b       NaN       NaN       NaN
# c  2.186361 -0.403839  1.233701
# d  1.543046  0.295324  0.455734
# e       NaN       NaN       NaN
# f -0.077444 -0.665241  0.953449
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.053098 -2.102404  0.848131
# b  2.186361 -0.403839  1.233701
# c  2.186361 -0.403839  1.233701
# d  1.543046  0.295324  0.455734
# e -0.077444 -0.665241  0.953449
# f -0.077444 -0.665241  0.953449
